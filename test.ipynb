# %%
from pathlib import Path

DATA       = Path('agent/data')
 
path = DATA / 'mitre_attack.json'
path.touch(exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 DATA       = Path('agent/data')
#       5 path = DATA / 'mitre_attack.json'
# ----> 6 path.touch(exist_ok=True)
#
# File c:\Users\PC\anaconda3\Lib\pathlib\_local.py:714, in Path.touch(self, mode, exist_ok)
#     712 if not exist_ok:
#     713     flags |= os.O_EXCL
# --> 714 fd = os.open(self, flags, mode)
#     715 os.close(fd)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'agent\\data\\mitre_attack.json'
